# %%
import pandas as pd
import networkx as nx

# %%
df_2011_2020 = pd.read_csv('data/g50_trade_2011_2020.csv', encoding='latin-1')

# %%
graph_2012 = nx.DiGraph()
for row in df_2011_2020[df_2011_2020['refPeriodId'] == 2012].itertuples():
    graph_2012.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %%
graph_2013 = nx.DiGraph()
for row in df_2011_2020[df_2011_2020['refPeriodId'] == 2013].itertuples():
    graph_2013.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %%
graph_2014 = nx.DiGraph()
for row in df_2011_2020[df_2011_2020['refPeriodId'] == 2014].itertuples():
    graph_2014.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %%
graph_2015 = nx.DiGraph()
for row in df_2011_2020[df_2011_2020['refPeriodId'] == 2015].itertuples():
    graph_2015.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %%
graph_2016 = nx.DiGraph()
for row in df_2011_2020[df_2011_2020['refPeriodId'] == 2016].itertuples():
    graph_2016.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %% [markdown]
# ## Saving Files

# %%
nx.write_edgelist(graph_2023, "2023_edgelist.csv", data=["weight"], delimiter=',')

# %%
adj_2024 = nx.adjacency_matrix(graph_2024, weight='weight')

# %%
nx.write_edgelist(graph_2024, "2024_edgelist.csv", data=["weight"], delimiter=',')

# %%
import numpy as np

np.savetxt("adj_2024.csv", adj_2024, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 import numpy as np
# ----> 3 np.savetxt("adj_2024.csv", adj_2024, delimiter=",")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_npyio_impl.py:1579, in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1577 # Handle 1-dimensional arrays
#    1578 if X.ndim == 0 or X.ndim > 2:
# -> 1579     raise ValueError(
#    1580         "Expected 1D or 2D array, got %dD array instead" % X.ndim)
#    1581 elif X.ndim == 1:
#    1582     # Common case -- 1d array of numbers
#    1583     if X.dtype.names is None:
#
# ValueError: Expected 1D or 2D array, got 0D array instead

# %%
import scipy as sp

sp.sparse.save_npz('adj_2024', adj_2024)

# %% [markdown]
# # Comparing 2012, 2013, 2014, 2015, 2016 (Crimea War)

# %% [markdown]
# ## PageRank

# %%
pr = nx.pagerank(graph_2012)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2012 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2012[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2012.values()
# Out:
# dict_values([0.013156310231773069, 0.016335256515870103, 0.08995911309020956, 0.055769868104385736, 0.0, 0.19985280128802982, 0.10496233823598723, 0.24891103530830846, 0.02321851351013593, 0.5470820393341234, 0.012010189373703255, 0.03963518958334029, 0.029726560310467, 0.024036820809194226, 0.021340381044060087, 0.32832474641051707, 0.5728519697972683, 0.17466642548541297, 0.07216226825921604, 0.03549895095338471, 0.024940478581296444, 0.0190087346747259, 0.22157084340149946, 0.2872902853639237, 0.0005625904506744237, 0.08203654553824177, 0.1785745632155479, 0.30094630346623447, 0.007125641085669683, 0.030355784277662043, 0.0023516844743409924, 0.0041178105071317615, 0.021347575980489124, 0.07739004383977724, 0.02038811834360703, 0.16772026830281256, 0.012870340640010743, 0.11770259132493542, 0.07630675804795668, 0.13709426238449293, 0.03333698507799561, 0.1523123575028635, 0.06279350766643968, 0.15019412955424846, 0.07411266983486806, 0.08938559976874834, 1.0, 0.11933400274442413, 
# ...

# %%
pr = nx.pagerank(graph_2013)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2013 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2013[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2013.values()
# Out:
# dict_values([0.01320903292773383, 0.017626236782535297, 0.08197363494632094, 0.05316464032153932, 0.0, 0.20202485597617628, 0.10473475623340495, 0.2473888896446265, 0.019399675186836943, 0.6125200028084528, 0.010530799936220912, 0.03822214066572216, 0.02805112331393054, 0.02275752099524368, 0.018951384999509387, 0.3223563100146496, 0.5639804869506417, 0.18067997420235418, 0.07128729436131899, 0.03396912917855588, 0.022699852013315897, 0.01680086490258161, 0.21838748709393282, 0.2713937760250445, 0.0015768546537950334, 0.08771243225676822, 0.18119356756261149, 0.29364296411687774, 0.006975004779129728, 0.02843336212454563, 0.002307230754399902, 0.0023209527730566237, 0.022045080787928734, 0.07750200426973745, 0.0199210325898218, 0.1692230156166319, 0.01195801169333032, 0.11676345747860821, 0.07656084044492055, 0.13866194414716934, 0.029544504974847646, 0.15376524566034977, 0.05793422473298091, 0.15316900407255746, 0.07193720164222851, 0.10606201374462566, 1.0, 0.13565703192887943, 0.3
# ...

# %%
pr = nx.pagerank(graph_2014)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2014 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2014[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2014.values()
# Out:
# dict_values([0.015828681345762298, 0.012292942507517215, 0.07688542819722237, 0.05236125890903984, 0.0041519120946235345, 0.20172259318830943, 0.09670957327855065, 0.2442858925992842, 0.01661765826478971, 0.5859548894856524, 0.013151187449763388, 0.041903465187764125, 0.029837295385720743, 0.027340379373885712, 0.0196881231291436, 0.3108119975782893, 0.5601898019062841, 0.16672779578216393, 0.0635697154834004, 0.03538844271737979, 0.026644268514533692, 0.01863360524967839, 0.21823558585891725, 0.2600820534156347, 0.0, 0.08220440381362785, 0.18952625496142922, 0.2864676462987263, 0.00932928892076506, 0.029699544195320556, 0.005596030399788716, 0.002659045137159375, 0.025034065165611467, 0.08135879263537482, 0.023262105450856663, 0.16746875264802252, 0.015079507232496172, 0.10250259268530314, 0.0777418453576216, 0.13094126933691622, 0.026273382900052916, 0.16063227726344914, 0.05890851935748202, 0.12731954645615154, 0.06376006951007261, 0.09616435652672692, 1.0, 0.12912484525866824, 0.
# ...

# %%
pr = nx.pagerank(graph_2015)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2015 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2015[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2015.values()
# Out:
# dict_values([0.015750719923976603, 0.015539720868872843, 0.0743152310102133, 0.05005075284649248, 0.009733828744589145, 0.18240679635641258, 0.07597058995562594, 0.23762833376785483, 0.01963655753633571, 0.5343304579091303, 0.01354770916542929, 0.04282546495685605, 0.02997376419762007, 0.027951870429968995, 0.0174119923737723, 0.28074254475788424, 0.5129014754016907, 0.1608666649085764, 0.05310649044029617, 0.03495937128214248, 0.030149115948933332, 0.020574859509143156, 0.1961690925425823, 0.22986801148793265, 0.0, 0.07463559331620365, 0.20120662337887313, 0.2466869967241628, 0.007769655345665185, 0.02814266861258068, 0.011660188177750172, 0.006820723515687105, 0.026839784012684803, 0.0792944025276793, 0.02438665901636558, 0.15562442195006704, 0.017243343573370946, 0.06385225747446821, 0.0830624458929075, 0.11937749908427783, 0.027312373134880354, 0.15440060888913656, 0.05500947175466113, 0.1284801079331219, 0.06336850493932937, 0.08832105102489364, 1.0, 0.137524935789651, 0.3102675
# ...

# %%
pr = nx.pagerank(graph_2016)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2016 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2016[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2016.values()
# Out:
# dict_values([0.014961366211976431, 0.014419794610811996, 0.07087994279092581, 0.05124692560960675, 0.010381842947565919, 0.18221240115388768, 0.06615609771288136, 0.23344790273508248, 0.01781755946754508, 0.5192556699473565, 0.010316082730538339, 0.04519824463178614, 0.030498276974433778, 0.023832618843078805, 0.01793385113705071, 0.2808286459350317, 0.5171219372439574, 0.1492641561913921, 0.0514937804884037, 0.030076188122997845, 0.03279481804498119, 0.02262971767293258, 0.20017925441311554, 0.22466323308607056, 0.0, 0.06865406950853754, 0.20315853215491012, 0.23896967875756506, 0.0032868295621111777, 0.028453579376186533, 0.012260910968932181, 0.006265387527541951, 0.029937197113639864, 0.08300966662149213, 0.025274569598607247, 0.15384573534655405, 0.018790314571231106, 0.06153740060101287, 0.06406599171312774, 0.1124509626443221, 0.023445259688279773, 0.15490044459609148, 0.05751359791591133, 0.1309552654606472, 0.061656509719619175, 0.08830926852040313, 1.0, 0.13372414069149724,
# ...

# %% [markdown]
# ## In Degree

# %%
in_degree_2012 = dict(graph_2012.in_degree(weight='weight'))
in_degree_2012 = {k: v for k, v in sorted(in_degree_2012.items(), key=lambda item: item[0], reverse=False)} # for sorting

in_degree_2012.values()
# Out:
# dict_values([28101537421.0, 49926201913.51, 158646544294.0, 122062670891.113, 33028190568.821, 246764219409.55, 154335375104.0, 379157333895.10297, 55054661682.879, 1590614336422.0, 23419922827.0, 135718699527.0, 75962943426.424, 16140367739.306, 49992231052.0, 434685853456.0, 1202026924697.663, 203520482167.0, 132010358678.0, 30643894860.33, 126816847817.098, 48519989000.0, 394266013716.18, 538099367777.0, 31709951755.0, 165987917344.0, 361411353190.0, 425894491335.02496, 28820025274.0, 84498027306.0, 16689416378.0, 33081964528.59, 46684364430.0, 166503479279.0, 48642608148.685, 404994155276.0, 49893970171.0, 232734218028.09, 34392222204.33, 256342153820.471, 46013047813.585, 246094581881.72598, 126416104852.053, 269802448749.067, 177204562465.03, 109304978372.0, 1283847763523.0, 65187705234.333, 370046350387.0, 158835287441.23])

# %% [markdown]
# ## CON

# %%
def con_score(g):
    con_scores = {} # dictionary of con scores, indices are node names, values are con scores
    for u in g:
        score = 0
        for v in g:
            if u != v:
                common_out_neighbors = set(g.successors(u)).intersection(set(g.successors(v)))
                score = score + len(common_out_neighbors)
        con_scores[u] = score

    return con_scores

def normalized_con_score(g):
    con_scores = {} # dictionary of con scores, indices are node names, values are con scores
    for u in g:
        score = 0
        for v in g:
            if u != v:
                common_out_neighbors = set(g.successors(u)).intersection(set(g.successors(v)))
                score = score + len(common_out_neighbors)
        con_scores[u] = score

    max_con = max(con_scores.values())
    min_con = min(con_scores.values())

    normalized_con_scores = {} # dictionary of con scores, indices are node names, values are normalized con scores
    for u in con_scores:
        normalized_con_scores[u] = (con_scores[u] - min_con) / (max_con - min_con)
    
    return normalized_con_scores

def normalized_weighted_con(g):
    con_scores = {} # dictionary of con scores, indices are node names, values are con scores
    for u in g:
        score = 0
        for v in g:
            if u != v:
                common_out_neighbors = set(g.successors(u)).intersection(set(g.successors(v)))
                for neighbour in common_out_neighbors:
                    score = score + min(g.edges[u,neighbour]['weight'], g.edges[v,neighbour]['weight'])
        con_scores[u] = score

    normalized_con_scores = {} # dictionary of con scores, indices are node names, values are normalized con scores
    max_con = max(con_scores.values())
    min_con = min(con_scores.values())
    for u in con_scores:
        normalized_con_scores[u] = (con_scores[u] - min_con) / (max_con - min_con)

    return normalized_con_scores

# %%
con_2012 = normalized_weighted_con(graph_2012)
con_2012 = {k: v for k, v in sorted(con_2012.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2012.values()
# Out:
# dict_values([0.2238154712061051, 0.19306735719923837, 0.4022021029972613, 0.362213754177504, 0.11116875688260337, 0.5590014742461671, 0.4721279650045093, 0.49009442375561685, 0.241450488739825, 1.0, 0.17295756239887847, 0.3301851983614077, 0.26173905567619477, 0.09222923373440732, 0.2240464561857597, 0.734083018855837, 0.9143469548784255, 0.5010716743297512, 0.3972900108285123, 0.0, 0.33942029217524683, 0.20799089701285658, 0.6993950234807433, 0.7552422674984919, 0.2316035062881424, 0.42194624407458464, 0.37614657014674513, 0.6777479542786873, 0.3470998453302997, 0.36664837369909586, 0.09095930621196807, 0.17327941414209078, 0.16338554733881216, 0.36386205063359106, 0.16902086061771462, 0.6360262255966248, 0.16369465937764682, 0.5904686951107697, 0.13397965177917576, 0.48992221973541367, 0.23547572403190944, 0.5022393726757306, 0.3909552921628571, 0.597619952999612, 0.4453690631936758, 0.3132421574565371, 0.8681520579026697, 0.18424276605325993, 0.7127651143797793, 0.3273327707115933
# ...

# %%
con_2013 = normalized_weighted_con(graph_2013)
con_2013 = {k: v for k, v in sorted(con_2013.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2013.values()
# Out:
# dict_values([0.14215765947800416, 0.12403553803438702, 0.3079153562647661, 0.3246429684686772, 0.04028143763911905, 0.5307513860026315, 0.41370090731280557, 0.44031074414716653, 0.17767404216205374, 1.0, 0.10470307909533522, 0.2859190832918475, 0.209743520500906, 0.01426384414033678, 0.16809407868415085, 0.7190404608719805, 0.9245309897762628, 0.5049876449204879, 0.3434885672426934, 0.0, 0.2824021647077295, 0.1482369999329327, 0.6915160135824314, 0.7104664654949134, 0.15551273132996818, 0.3740005727363467, 0.3193693212011103, 0.6511890363738352, 0.18641633888853434, 0.3037119120857603, 0.02200708501648751, 0.09929506616640456, 0.10986514031164082, 0.3448777519871374, 0.10915051825741265, 0.6224872964802137, 0.11770202728751891, 0.5577407876902775, 0.07368752452979697, 0.4479916990759365, 0.16958263850363112, 0.4827137535571644, 0.3336474381411574, 0.5891467427330155, 0.39824568189732423, 0.2775591224694427, 0.8672057407670407, 0.09007467092197363, 0.7107277765038668, 0.31080461304360
# ...

# %%
con_2014 = normalized_weighted_con(graph_2014)
con_2014 = {k: v for k, v in sorted(con_2014.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2014.values()
# Out:
# dict_values([0.19199667152837904, 0.17155372191685522, 0.3623444764493433, 0.373192874608725, 0.0, 0.5595393273666268, 0.44274526091066907, 0.48132848794623345, 0.2279124028101194, 1.0, 0.16395545893000302, 0.35133711776282617, 0.2659441563593251, 0.07846668954342258, 0.22694462025160747, 0.7331952538098434, 0.920581094942379, 0.5107105288841469, 0.37959888310128637, 0.08484672808161738, 0.33637381368020414, 0.20914799190725022, 0.7133450359418742, 0.7153384950692558, 0.20294431594462153, 0.4158180949006174, 0.3724429726936326, 0.6786783330159564, 0.24529004917082017, 0.3366626032290453, 0.0929719017678046, 0.13678316179872083, 0.1779025478533006, 0.39955338421262493, 0.17504033649005532, 0.646312933269533, 0.18654548333550514, 0.5677198741889383, 0.1504375272629151, 0.4750196872497777, 0.219727275304936, 0.5221450340223468, 0.37365385258510164, 0.5976394416750288, 0.4356047348980104, 0.33273591634321226, 0.8632485829219256, 0.1635902639349685, 0.7230986697867114, 0.3860875302204816]
# ...

# %%
con_2015 = normalized_weighted_con(graph_2015)
con_2015 = {k: v for k, v in sorted(con_2015.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2015.values()
# Out:
# dict_values([0.06290174623885658, 0.10764282807730823, 0.30031724627019774, 0.3127163726415012, 0.08236327792954139, 0.48703128511956223, 0.38680397287489293, 0.44662334515270885, 0.15156260813046282, 1.0, 0.056474402782814265, 0.29890787093068616, 0.20242345465666803, 0.0, 0.15193030869221957, 0.7008723041690899, 0.8996651634354257, 0.45986544192147333, 0.3270235705168745, 0.006591615358614221, 0.31742272326719084, 0.1568991595283779, 0.6788858342874216, 0.7029844133328434, 0.08409942962748293, 0.37175407505446234, 0.348118430568272, 0.62641354581655, 0.09301009862814727, 0.2488627310869103, 0.022445874015220982, 0.07773200327747631, 0.1196924017745721, 0.3489383752051554, 0.10947837573125252, 0.6270682338479243, 0.11878102058761449, 0.45688026391233194, 0.07916240582620819, 0.44220179952050687, 0.15580709795540845, 0.4760967777140159, 0.3158133429019112, 0.5726952108238978, 0.40743523260399667, 0.2904084724722128, 0.8494753046145135, 0.11235844087675434, 0.7081934879712076, 0.38925
# ...

# %%
con_2016 = normalized_weighted_con(graph_2016)
con_2016 = {k: v for k, v in sorted(con_2016.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2016.values()
# Out:
# dict_values([0.05145601029615606, 0.11702530477131509, 0.30613452624258986, 0.3184170340485253, 0.09297636272449605, 0.5331811388109428, 0.3802940053032898, 0.44914257624012205, 0.14698668820415586, 1.0, 0.03815368003359286, 0.3104100204986735, 0.20568912327471484, 0.0, 0.14591862390965551, 0.719640727513194, 0.9086313162167441, 0.46372684033540795, 0.3261384383898798, 0.03707703781463561, 0.3397935649166375, 0.15064221326116656, 0.7013451582845001, 0.7309161456301436, 0.05801937628643752, 0.3665574286884242, 0.35717451560079566, 0.6477776601260731, 0.05333519953237751, 0.22326205226359325, 0.015496551558077621, 0.08036305317267142, 0.11543513052610258, 0.3604334389603035, 0.10941673458949035, 0.6148536089981522, 0.125978119765269, 0.4912880020033116, 0.06736327680148835, 0.44095623426991715, 0.14931182583913105, 0.4956968510599108, 0.3178592370399423, 0.6142740879799002, 0.414614827076995, 0.2962694656745463, 0.853455042846387, 0.13394536918809632, 0.6843768845958607, 0.422943235886
# ...

# %% [markdown]
# ## Clustering

# %%
betweenness = nx.betweenness_centrality(graph_2021)
betweenness_sorted = {k: v for k, v in sorted(betweenness.items(), key=lambda item: item[1], reverse=True)} # for sorting
betweenness_sorted
# Out:
# {'Argentina': 0.00013915281655722673,
#  'Australia': 0.00013915281655722673,
#  'Austria': 0.00013915281655722673,
#  'Belgium': 0.00013915281655722673,
#  'Brazil': 0.00013915281655722673,
#  'Canada': 0.00013915281655722673,
#  'Chile': 0.00013915281655722673,
#  'China': 0.00013915281655722673,
#  'Czechia': 0.00013915281655722673,
#  'Denmark': 0.00013915281655722673,
#  'Finland': 0.00013915281655722673,
#  'France': 0.00013915281655722673,
#  'Germany': 0.00013915281655722673,
#  'Indonesia': 0.00013915281655722673,
#  'Ireland': 0.00013915281655722673,
#  'Italy': 0.00013915281655722673,
#  'Japan': 0.00013915281655722673,
#  'Rep. of Korea': 0.00013915281655722673,
#  'Netherlands': 0.00013915281655722673,
#  'Norway': 0.00013915281655722673,
#  'Philippines': 0.00013915281655722673,
#  'Poland': 0.00013915281655722673,
#  'Portugal': 0.00013915281655722673,
#  'Romania': 0.00013915281655722673,
#  'Russian Federation': 0.00013915281655722673,
# ...
