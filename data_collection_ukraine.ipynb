# %%
import pandas as pd
import networkx as nx

# %%
df_2021_2024 = pd.read_csv('data/g50_trade_2021_2024.csv', encoding='latin-1')

# %%
for row in df_2021_2024[df_2021_2024['refPeriodId'] == 2021].itertuples():
    a = row
(row.reporterISO, row.partnerISO, row.fobvalue)
# Out:
# ('USA', 'United Kingdom', 61430610436.0)

# %%
graph_2021 = nx.DiGraph()
for row in df_2021_2024[df_2021_2024['refPeriodId'] == 2021].itertuples():
    graph_2021.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %%
nx.write_gexf(graph_2021, path='g50_2021.gexf')

# %%
graph_2022 = nx.DiGraph()
for row in df_2021_2024[df_2021_2024['refPeriodId'] == 2022].itertuples():
    graph_2022.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %%
graph_2023 = nx.DiGraph()
for row in df_2021_2024[df_2021_2024['refPeriodId'] == 2023].itertuples():
    graph_2023.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %%
graph_2024 = nx.DiGraph()
for row in df_2021_2024[df_2021_2024['refPeriodId'] == 2024].itertuples():
    graph_2024.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %%
df_2011_2020 = pd.read_csv('data/g50_trade_2011_2020.csv', encoding='latin-1')

# %%
graph_2020 = nx.DiGraph()
for row in df_2011_2020[df_2011_2020['refPeriodId'] == 2020].itertuples():
    graph_2020.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %% [markdown]
# ## Saving Files

# %%
nx.write_edgelist(graph_2023, "2023_edgelist.csv", data=["weight"], delimiter=',')

# %%
adj_2024 = nx.adjacency_matrix(graph_2024, weight='weight')

# %%
nx.write_edgelist(graph_2024, "2024_edgelist.csv", data=["weight"], delimiter=',')

# %%
import numpy as np

np.savetxt("adj_2024.csv", adj_2024, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 import numpy as np
# ----> 3 np.savetxt("adj_2024.csv", adj_2024, delimiter=",")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_npyio_impl.py:1579, in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1577 # Handle 1-dimensional arrays
#    1578 if X.ndim == 0 or X.ndim > 2:
# -> 1579     raise ValueError(
#    1580         "Expected 1D or 2D array, got %dD array instead" % X.ndim)
#    1581 elif X.ndim == 1:
#    1582     # Common case -- 1d array of numbers
#    1583     if X.dtype.names is None:
#
# ValueError: Expected 1D or 2D array, got 0D array instead

# %%
import scipy as sp

sp.sparse.save_npz('adj_2024', adj_2024)

# %% [markdown]
# # Comparing 2021, 2022, 2023, 2024 (Ukraine War)

# %% [markdown]
# ## PageRank

# %%
pr = nx.pagerank(graph_2020)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2020 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2020[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2020.values()
# Out:
# dict_values([0.0036376349913165404, 0.003394887095430656, 0.0676061530187876, 0.04837754801409948, 0.008374487693313844, 0.1586967163069216, 0.06327583670671875, 0.2272279504302999, 0.013717166464317598, 0.6290709074906047, 0.0059232898936687275, 0.0463913393840017, 0.029535982280233037, 0.02140791386617893, 0.015202915056533525, 0.24932127317363728, 0.5109269168585461, 0.1233126736643126, 0.04236016419036494, 0.0, 0.03447343917263666, 0.01786835608868963, 0.18339664975825587, 0.20719451439065847, 0.00047359511579069056, 0.06520806813732667, 0.18479250617380022, 0.2438600709877761, 0.004881221632066257, 0.025975942269625175, 0.007742751771282808, 0.002409152456179514, 0.028111466867789203, 0.09671601604458006, 0.023286858837287445, 0.15964651112853917, 0.0202319381162811, 0.06789595538100215, 0.06026171271788969, 0.10314085799810589, 0.01636178669513971, 0.13618848630473512, 0.05383501298003391, 0.11415113657250718, 0.05719558409052985, 0.08149465868088343, 1.0, 0.08363254026990123, 
# ...

# %%
pr = nx.pagerank(graph_2021)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2021 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2021[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2021.values()
# Out:
# dict_values([0.0023381219629430277, 0.007319019458048479, 0.06761829644161031, 0.05173726523410379, 0.014641681491107967, 0.17324912930125835, 0.07463997147615292, 0.22295075724693794, 0.020399490709396617, 0.6222427392092778, 0.010334117333815536, 0.04833110379827577, 0.029734372596649634, 0.023642203498626942, 0.01592333230468376, 0.2521140889449806, 0.5082971518853272, 0.15417320530439668, 0.0495435804946729, 0.0009675579971547123, 0.03431217125754321, 0.020983606089158727, 0.1912297220541826, 0.19901147574933, 0.0, 0.06657621907304051, 0.20023724661746975, 0.2503920344868397, 0.007855699175833718, 0.02495497120800571, 0.010725621897698665, 0.005706637712977772, 0.030938226820963637, 0.10336180601314168, 0.026188014988168293, 0.16220765677063903, 0.021877661265926846, 0.06952343460026184, 0.05072165262735226, 0.09834042490514212, 0.018698991188309026, 0.14515166022296838, 0.05287921998140112, 0.11407114029695573, 0.05875975972670571, 0.0817620655475439, 1.0, 0.08034437350826258, 0
# ...

# %%
pr = nx.pagerank(graph_2022)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2022 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2022[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2022.values()
# Out:
# dict_values([0.0029031040071830967, 0.011986020706772052, 0.07180441292916556, 0.05467985796001433, 0.01571716921491992, 0.1845691375216155, 0.0772413535767215, 0.221799582047906, 0.02213437847767142, 0.5480627594944381, 0.013514602675066953, 0.049892591123533794, 0.0300839374700904, 0.021121491322759377, 0.01648691128258173, 0.26008262870241916, 0.5142275442335754, 0.1548269610857003, 0.05659430940230116, 0.0021814142989808553, 0.03760754037596392, 0.02480461538250359, 0.194352653743478, 0.19487072892086021, 0.0, 0.07185751344120732, 0.20360354372619882, 0.26916684577072075, 0.009958505847503579, 0.026794307922053427, 0.008900253434104624, 0.007877554089761266, 0.033127414626863305, 0.10444004146545904, 0.030088356632363353, 0.15901387937675207, 0.024648731155023303, 0.044001050827298806, 0.0545156282667709, 0.1090851546218209, 0.02203340668801236, 0.15352022989966208, 0.05432619511931892, 0.11453159574412142, 0.06115956788397901, 0.0873677053335713, 1.0, 0.0871642725323045, 0.23331
# ...

# %%
pr = nx.pagerank(graph_2023)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2023 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2023[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2023.values()
# Out:
# dict_values([0.004838212955316825, 0.009916207613972156, 0.07288454702917707, 0.051466900127937615, 0.010661779260301662, 0.17586077535010888, 0.07160393665807109, 0.2247406535288111, 0.018364372942402056, 0.5294569769573414, 0.009514756810458627, 0.049768809926058324, 0.02926725452284139, 0.017887216718518516, 0.01536988874753192, 0.2565887550677046, 0.49235683305665173, 0.14745591578880354, 0.05230215060960638, 0.0, 0.03892828397080409, 0.01995746445946928, 0.1952593799918504, 0.17653815739782, 0.0042308429573766895, 0.06709719378692817, 0.21131149496857288, 0.2642390516275015, 0.005647251082715391, 0.024107602425546597, 0.003325568906714841, 0.006353438383628623, 0.02882666521009882, 0.10873315739822664, 0.02906783329824513, 0.14546028181030338, 0.02709809092427125, 0.04611705228037065, 0.06330555573703707, 0.1030806421225518, 0.02093161743096505, 0.14941042742644584, 0.05410470209601871, 0.1145959254859142, 0.056834136201938196, 0.09689130285338696, 1.0, 0.09950708966668335, 0.23
# ...

# %%
pr = nx.pagerank(graph_2024)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2024 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2024[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2024.values()
# Out:
# dict_values([0.009480088777425257, 0.01092744008118631, 0.0732539996101501, 0.05290669150853775, 0.012312741309350091, 0.1697148595921897, 0.0801263468650961, 0.22221184357735377, 0.022097195553382385, 0.5045146551139825, 0.013938030322836801, 0.054931345787076584, 0.03586099093690888, 0.019107848604233226, 0.019728406924681603, 0.2599855960063375, 0.49201297518807946, 0.13408967600309402, 0.05576282231247997, 0.0, 0.04129674029189977, 0.018682380215930328, 0.19991737928211176, 0.1707954419377989, 0.006460274256299384, 0.07755604553765735, 0.21712881149462787, 0.26656807994497056, 0.008031807769304223, 0.030585968764420098, 0.006384132562787287, 0.010430572337419055, 0.031169008903844, 0.11778759329426297, 0.035441540780361463, 0.13591349706385625, 0.033062301483012944, 0.04232520624460971, 0.050935122444446104, 0.10607015426082889, 0.02082509476569371, 0.15827442893693625, 0.05848657289400029, 0.10947151439587392, 0.05974428256587229, 0.08298395998547645, 1.0, 0.11443506617443466, 0
# ...

# %% [markdown]
# ## In Degree

# %%
in_degree_2020 = dict(graph_2020.in_degree(weight='weight'))
in_degree_2020 = {k: v for k, v in sorted(in_degree_2020.items(), key=lambda item: item[0], reverse=False)} # for sorting

in_degree_2020.values()
# Out:
# %%
out_degree_2024 = dict(graph_2024.out_degree(weight='weight'))
out_degree_2024 = {k: v for k, v in sorted(out_degree_2024.items(), key=lambda item: item[0], reverse=False)} # for sorting

out_degree_2024.values()
# Out:
# dict_values([0, 66976222650.35, 248842148220.622, 176917057286.243, 0, 338568910332.595, 300083793149.0, 537079983619.872, 92762301222.216, 2832767489649.0, 36863929121.73, 214377929360.0, 95703939203.204, 29853001589.333, 65076149420.497, 574328057409.298, 1451826929649.491, 355801008289.92, 243794048484.763, 0, 235011436426.752, 47595280000.0, 551049632243.207, 591984552496.636, 70294993260.22, 279896533014.695, 577518532685.0, 625502483536.828, 46518680405.561005, 159537546787.885, 26700911367.716, 68981112484.618, 59574703615.0, 312724913097.0, 73738576548.661, 566394491656.0, 75290996833.86, 0, 63926645539.7, 382487079569.076, 66102247230.273, 333116171766.45703, 177677107028.585, 385805389687.102, 254074602156.61, 178520886025.0, 1839631850247.0, 0, 435941812503.093, 0])

# %% [markdown]
# ## CON

# %%
def con_score(g):
    con_scores = {} # dictionary of con scores, indices are node names, values are con scores
    for u in g:
        score = 0
        for v in g:
            if u != v:
                common_out_neighbors = set(g.successors(u)).intersection(set(g.successors(v)))
                score = score + len(common_out_neighbors)
        con_scores[u] = score

    return con_scores

def normalized_con_score(g):
    con_scores = {} # dictionary of con scores, indices are node names, values are con scores
    for u in g:
        score = 0
        for v in g:
            if u != v:
                common_out_neighbors = set(g.successors(u)).intersection(set(g.successors(v)))
                score = score + len(common_out_neighbors)
        con_scores[u] = score

    max_con = max(con_scores.values())
    min_con = min(con_scores.values())

    normalized_con_scores = {} # dictionary of con scores, indices are node names, values are normalized con scores
    for u in con_scores:
        normalized_con_scores[u] = (con_scores[u] - min_con) / (max_con - min_con)
    
    return normalized_con_scores

def normalized_weighted_con(g):
    con_scores = {} # dictionary of con scores, indices are node names, values are con scores
    for u in g:
        score = 0
        for v in g:
            if u != v:
                common_out_neighbors = set(g.successors(u)).intersection(set(g.successors(v)))
                for neighbour in common_out_neighbors:
                    score = score + min(g.edges[u,neighbour]['weight'], g.edges[v,neighbour]['weight'])
        con_scores[u] = score

    normalized_con_scores = {} # dictionary of con scores, indices are node names, values are normalized con scores
    max_con = max(con_scores.values())
    min_con = min(con_scores.values())
    for u in con_scores:
        normalized_con_scores[u] = (con_scores[u] - min_con) / (max_con - min_con)

    return normalized_con_scores

# %%
con_2020 = normalized_weighted_con(graph_2020)
con_2020 = {k: v for k, v in sorted(con_2020.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2020.values()
# Out:
# dict_values([0.0, 0.15696782029368253, 0.38906581808875595, 0.3774200474724053, 0.0, 0.569717172514565, 0.4425287972750778, 0.5040068136129616, 0.22915085459010015, 1.0, 0.11048118073270233, 0.3728151076891061, 0.2543625017407764, 0.08870819255189172, 0.2155922766564986, 0.7138960486418705, 0.9229937441348456, 0.515928041439815, 0.38344063332167694, 0.07179272230540253, 0.45793847241405267, 0.18054887262359368, 0.7260705940532292, 0.7377160610672385, 0.1349590601499873, 0.4400171199988239, 0.4025883377517951, 0.6955596975036661, 0.1133480588033149, 0.2602702059596889, 0.09168743798698287, 0.15133109249380713, 0.19400084012119342, 0.43689396029586464, 0.1772996079250258, 0.6559878550784035, 0.19334157068370236, 0.5444153012023679, 0.14831053976216071, 0.5191170310849098, 0.22745167621614865, 0.524968659805406, 0.3749756186044364, 0.6441539730517457, 0.4592877719602723, 0.35022786896160507, 0.8550381615907557, 0.2423972678855969, 0.6638933912465397, 0.5533113655845399])

# %%
con_2021 = normalized_weighted_con(graph_2021)
con_2021 = {k: v for k, v in sorted(con_2021.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2021.values()
# Out:
# dict_values([0.0, 0.17277110881828928, 0.3768549008763958, 0.36509774421169927, 0.0, 0.5771782070927943, 0.4654516008821491, 0.4860356996423638, 0.23509252430217173, 1.0, 0.11681845012013857, 0.35835053153436414, 0.24133070508910962, 0.10417891133043045, 0.2146266619952755, 0.70224359288025, 0.9124796146972707, 0.5517219990390445, 0.414554014265583, 0.10311114970788703, 0.4185598337648409, 0.1730852258130354, 0.717536072591841, 0.7212160618377295, 0.13503343096006143, 0.4510072966813007, 0.37417192797209875, 0.6818885287532441, 0.12590969050010037, 0.33902531489965, 0.09685504462179836, 0.16847971203477938, 0.1844406248668663, 0.43024656691944996, 0.17491579952267194, 0.6618057022133008, 0.19122168401394962, 0.6040946025118074, 0.16651575868424362, 0.4979638991167017, 0.25908240203169686, 0.5206416615806574, 0.36129690775650414, 0.6184420030322011, 0.45026935045623495, 0.3625546788061703, 0.8489507453608779, 0.24812930403042735, 0.6324182035812471, 0.5391187451858142])

# %%
con_2022 = normalized_weighted_con(graph_2022)
con_2022 = {k: v for k, v in sorted(con_2022.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2022.values()
# Out:
# dict_values([0.0, 0.174691532477061, 0.37628569954652813, 0.3401731140050907, 0.0, 0.5688253720049302, 0.47643518098668797, 0.48812913111930106, 0.2142000611635747, 1.0, 0.13345042847436558, 0.3389677686855242, 0.21418013172424546, 0.11575930746412412, 0.20566979354772114, 0.6669782607141594, 0.8760294753565567, 0.5348495901728593, 0.42098921210687956, 0.09555199525181085, 0.4150859927650933, 0.1803113079987158, 0.6919405872268624, 0.6752089864205998, 0.1590347528506779, 0.4484841903528889, 0.3760963140001794, 0.649722535234017, 0.14753543565986874, 0.3615649327969897, 0.09318635319947448, 0.15489730836874543, 0.17297534375347634, 0.42670804148548336, 0.17094027849104437, 0.6377857162475322, 0.17930600447611011, 0.0, 0.1641280365541817, 0.48922320444095835, 0.23259268302552194, 0.4940180109163903, 0.33623861452358955, 0.5950439692425041, 0.4329698478056017, 0.34635424586555547, 0.8464477918498067, 0.2589286862830933, 0.6283393343281372, 0.5277763686872143])

# %%
con_2023 = normalized_weighted_con(graph_2023)
con_2023 = {k: v for k, v in sorted(con_2023.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2023.values()
# Out:
# dict_values([0.0, 0.1359467745273582, 0.3710677084564754, 0.36772907250287895, 0.0, 0.5362505524515984, 0.4773533981584015, 0.4828298684123839, 0.2146469491956272, 1.0, 0.12369100892228505, 0.35289072478562084, 0.2316964315458559, 0.09042221801178817, 0.20512952773586707, 0.7044980397168221, 0.9034304337290828, 0.5399582506789278, 0.3961036520672086, 0.0, 0.4148042001599921, 0.16162943401685853, 0.717659145849301, 0.6969257837988296, 0.15602904259900285, 0.4256758199143522, 0.39220515843637305, 0.6632933390048247, 0.16067152156669248, 0.3043762088347455, 0.08886445103159042, 0.1683175529050083, 0.1698309113277842, 0.4463455390492769, 0.17807020696153852, 0.6454846647399087, 0.19151165947210266, 0.0, 0.13902146593409961, 0.48707505016910185, 0.21006223377847508, 0.5007661629328892, 0.35210782431763393, 0.6118181356099305, 0.43887058447197363, 0.3548033498262731, 0.8538396717066076, 0.27418303657602555, 0.643368933375214, 0.526224848606881])

# %%
con_2024 = normalized_weighted_con(graph_2024)
con_2024 = {k: v for k, v in sorted(con_2024.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2024.values()
# Out:
# dict_values([0.0, 0.1522251137844357, 0.3559102654412087, 0.35250181065942976, 0.0, 0.523080115703013, 0.4700978083624893, 0.4765751186447943, 0.21617456739359578, 1.0, 0.11641976202902865, 0.35681126836413085, 0.2328828891423462, 0.08988913997114358, 0.1843055273694431, 0.6964319085090998, 0.8749412084198384, 0.5361596702717153, 0.39491332534868695, 0.0, 0.4367304017202537, 0.1493397990748136, 0.6906405467611884, 0.6692474031422772, 0.1544796152660053, 0.4274741392827333, 0.3830620580022221, 0.6509994833585343, 0.1330962348842007, 0.29664779325444446, 0.09292506414185889, 0.18101233633880248, 0.16291587198373905, 0.4426850849435896, 0.1743103815798814, 0.6365719469340944, 0.18815292828546076, 0.0, 0.14380741742787356, 0.47244893818475103, 0.1948180643028064, 0.48637302236228314, 0.34467029309986913, 0.6182459457222468, 0.44244687770852364, 0.3581463501219557, 0.8422672655414606, 0.0, 0.6326723016852959, 0.0])

# %% [markdown]
# ## Clustering

# %%
betweenness = nx.betweenness_centrality(graph_2021)
betweenness_sorted = {k: v for k, v in sorted(betweenness.items(), key=lambda item: item[1], reverse=True)} # for sorting
betweenness_sorted
# Out:
# {'Argentina': 0.00013915281655722673,
#  'Australia': 0.00013915281655722673,
#  'Austria': 0.00013915281655722673,
#  'Belgium': 0.00013915281655722673,
#  'Brazil': 0.00013915281655722673,
#  'Canada': 0.00013915281655722673,
#  'Chile': 0.00013915281655722673,
#  'China': 0.00013915281655722673,
#  'Czechia': 0.00013915281655722673,
#  'Denmark': 0.00013915281655722673,
#  'Finland': 0.00013915281655722673,
#  'France': 0.00013915281655722673,
#  'Germany': 0.00013915281655722673,
#  'Indonesia': 0.00013915281655722673,
#  'Ireland': 0.00013915281655722673,
#  'Italy': 0.00013915281655722673,
#  'Japan': 0.00013915281655722673,
#  'Rep. of Korea': 0.00013915281655722673,
#  'Netherlands': 0.00013915281655722673,
#  'Norway': 0.00013915281655722673,
#  'Philippines': 0.00013915281655722673,
#  'Poland': 0.00013915281655722673,
#  'Portugal': 0.00013915281655722673,
#  'Romania': 0.00013915281655722673,
#  'Russian Federation': 0.00013915281655722673,
# ...
