# %%
import pandas as pd
import networkx as nx

# %%
df_2001_2010 = pd.read_csv('data/g50_trade_2001_2010.csv', encoding='latin-1')

# %%
graph_2006 = nx.DiGraph()
for row in df_2001_2010[df_2001_2010['refPeriodId'] == 2006].itertuples():
    graph_2006.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %%
graph_2007 = nx.DiGraph()
for row in df_2001_2010[df_2001_2010['refPeriodId'] == 2007].itertuples():
    graph_2007.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %%
graph_2008 = nx.DiGraph()
for row in df_2001_2010[df_2001_2010['refPeriodId'] == 2008].itertuples():
    graph_2008.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %%
graph_2009 = nx.DiGraph()
for row in df_2001_2010[df_2001_2010['refPeriodId'] == 2009].itertuples():
    graph_2009.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %%
graph_2010 = nx.DiGraph()
for row in df_2001_2010[df_2001_2010['refPeriodId'] == 2010].itertuples():
    graph_2010.add_edge(row.reporterISO, row.partnerISO, weight=row.fobvalue)

# %% [markdown]
# ## Saving Files

# %%
nx.write_edgelist(graph_2023, "2023_edgelist.csv", data=["weight"], delimiter=',')

# %%
adj_2024 = nx.adjacency_matrix(graph_2024, weight='weight')

# %%
nx.write_edgelist(graph_2024, "2024_edgelist.csv", data=["weight"], delimiter=',')

# %%
import numpy as np

np.savetxt("adj_2024.csv", adj_2024, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 import numpy as np
# ----> 3 np.savetxt("adj_2024.csv", adj_2024, delimiter=",")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_npyio_impl.py:1579, in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1577 # Handle 1-dimensional arrays
#    1578 if X.ndim == 0 or X.ndim > 2:
# -> 1579     raise ValueError(
#    1580         "Expected 1D or 2D array, got %dD array instead" % X.ndim)
#    1581 elif X.ndim == 1:
#    1582     # Common case -- 1d array of numbers
#    1583     if X.dtype.names is None:
#
# ValueError: Expected 1D or 2D array, got 0D array instead

# %%
import scipy as sp

sp.sparse.save_npz('adj_2024', adj_2024)

# %% [markdown]
# # Comparing 2006, 2007, 2008, 2009, 2010 (Housing Crisis)

# %% [markdown]
# ## PageRank

# %%
pr = nx.pagerank(graph_2006)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2006 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2006[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2006.values()
# Out:
# dict_values([0.008150303023620561, 0.012444466768722025, 0.06573076581241356, 0.06506991692677905, 0.0, 0.20280691930820738, 0.05323362066730304, 0.2712235473760273, 0.015732568560652055, 0.2924823809655134, 0.008380517081881473, 0.03961609216987669, 0.04270147171229135, 0.014801997196959118, 0.0365577619431962, 0.3593299244110935, 0.5513395083943368, 0.08632337131446025, 0.03539743209072813, 0.023503584849037785, 0.049113906624068636, 0.02340815365254409, 0.26691901277551655, 0.3209289142585203, 0.004395026020858381, 0.06296553468844678, 0.1633249522448156, 0.25770834819100863, 0.006381447676972863, 0.03291185499585503, 0.008588753613273598, 0.001783798983311548, 0.02158467365748781, 0.06426501684674771, 0.04381633861160989, 0.13004710759579932, 0.02143756433707662, 0.08157957942288685, 0.03512502056783164, 0.10510722399106781, 0.02954147891507714, 0.20903138756461426, 0.07108648928732621, 0.10846572268680502, 0.047988594173670886, 0.06535045534736415, 1.0, 0.077749661551526, 0.3347
# ...

# %%
pr = nx.pagerank(graph_2007)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2007 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2007[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2007.values()
# Out:
# dict_values([0.010395850554636784, 0.016278255131379562, 0.07217989007367619, 0.06883296941013971, 0.0, 0.22699272974723872, 0.06700180424956284, 0.26793555391172796, 0.018417579022995716, 0.3387428536686708, 0.010364197089395928, 0.04748158306553954, 0.04459219806797335, 0.019820194200793614, 0.04021649645499419, 0.37282124041474746, 0.6014157601700864, 0.11955371340596296, 0.041645242885426294, 0.027985063467089028, 0.05471241380648872, 0.026126714452281333, 0.28357022776067564, 0.31283344384651, 0.008150979708431714, 0.06708280754209638, 0.15602735178511407, 0.28865058441811947, 0.009163552172753296, 0.039985174055138295, 0.00798406993790071, 0.0031367709173500615, 0.0225615684619795, 0.08034720178417207, 0.04546291978456337, 0.13984808766826648, 0.023522744947505905, 0.1064890701062404, 0.04318280165968386, 0.1126007477811988, 0.03257187626935092, 0.22574216149094242, 0.08003929031353889, 0.11804894366754068, 0.05036277875895896, 0.07439626329578133, 1.0, 0.09170795847539187, 0.3
# ...

# %%
pr = nx.pagerank(graph_2008)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2008 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2008[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2008.values()
# Out:
# dict_values([0.014247108655994722, 0.019073800742890737, 0.08240011122400488, 0.07240850485792735, 0.0, 0.23616783930829474, 0.08735848749685808, 0.2568288386910095, 0.02146613040039174, 0.37091701927254284, 0.010096071801691524, 0.05225299681050931, 0.04554705348098959, 0.02501502002200558, 0.040124360553511575, 0.3936867449221883, 0.6516197285863465, 0.141173768630759, 0.050922046772860774, 0.029947044418424346, 0.04800580958823433, 0.025303764136514584, 0.2984667334436151, 0.3319642902230687, 0.00485452617429961, 0.07172670985345905, 0.157029923267771, 0.32276059504859306, 0.013501361064501775, 0.03940028744905945, 0.0067348717856174495, 0.004604139129338826, 0.022845261360067492, 0.0948157309237623, 0.04636214451979212, 0.15091712275529895, 0.02666353701834863, 0.1291298037726523, 0.052222111329855186, 0.12475868000325342, 0.03386899733170799, 0.22293195813858419, 0.0802701982350214, 0.1338551089261404, 0.05695856015715794, 0.08574521117255535, 1.0, 0.11515800215411465, 0.3683759
# ...

# %%
pr = nx.pagerank(graph_2009)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2009 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2009[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2009.values()
# Out:
# dict_values([0.01883052877911221, 0.0137716074149233, 0.08220277333089171, 0.07246675216379667, 0.0, 0.22654102609181614, 0.08351408554775093, 0.25725570356813976, 0.01622048778252552, 0.4548168283663013, 0.008539583810531964, 0.04729853513094507, 0.041186934929845855, 0.02964031237917642, 0.02855643389504977, 0.40718362620023607, 0.6479081624256874, 0.17858839081096406, 0.05119293945767674, 0.0504695723124541, 0.04077565602164565, 0.020059138654885202, 0.28344862414149485, 0.261037376160908, 0.0025029183259633004, 0.07250451113925668, 0.15708282052939504, 0.3089380368069266, 0.012790399147667365, 0.038028835289782126, 0.008608216759962869, 0.0006435414222672524, 0.02068074956630735, 0.08672418875549803, 0.04455288788582338, 0.1523631686795525, 0.018567532180538953, 0.08812445088043297, 0.061473274111611485, 0.1262951229612378, 0.02841608350610153, 0.2101821434541138, 0.06989442115100583, 0.1533981529057086, 0.05456927936089709, 0.07687677309295066, 1.0, 0.12642664315550256, 0.365473
# ...

# %%
pr = nx.pagerank(graph_2010)
pr = {k: v for k, v in sorted(pr.items(), key=lambda item: item[0], reverse=False)} # for sorting

pr_normalized_2010 = {}
pr_max = max(pr.values())
pr_min = min(pr.values())
for u in pr:
    pr_normalized_2010[u] = (pr[u] - pr_min) / (pr_max - pr_min)

pr_normalized_2010.values()
# Out:
# dict_values([0.011405825754154943, 0.017829673050441357, 0.07877749004573557, 0.06448243894876857, 0.00039325614549679856, 0.21636169012622708, 0.1019713104688508, 0.2552351000190869, 0.01693460437024746, 0.5292143088447331, 0.007817457915879367, 0.04534800391527392, 0.033707165621107885, 0.026587471816085215, 0.025044362737267678, 0.370790964605057, 0.626231117806973, 0.19138138699821491, 0.05813074557089267, 0.04255402431842505, 0.029826422536357738, 0.02019739046053492, 0.2705882390651694, 0.27161224854901134, 0.0, 0.07638332827840387, 0.16445170918373472, 0.30965729471609515, 0.007313967169892294, 0.03334250724485935, 0.0075123440469159735, 0.0008692462971010891, 0.022817773491369438, 0.08415884927971302, 0.03628273647981556, 0.16470138917247784, 0.01539712890026234, 0.1004577768414337, 0.05382629433423528, 0.13028554284567861, 0.03023897941711181, 0.19207463353175508, 0.07042459277389888, 0.1422449281368941, 0.05860970235149158, 0.08773113098363232, 1.0, 0.11821508164668046, 0.3
# ...

# %% [markdown]
# ## In Degree

# %%
in_degree_2008 = dict(graph_2008.in_degree(weight='weight'))
in_degree_2008 = {k: v for k, v in sorted(in_degree_2008.items(), key=lambda item: item[0], reverse=False)} # for sorting

in_degree_2008.values()
# Out:
# dict_values([54247366448.0, 58173498730.0, 185178412557.0, 124619501538.0, 18148970309.0, 246575052119.18, 166243861324.0, 375691097188.0, 63987450589.305, 1196329929084.0, 31909308173.0, 110526906383.0, 78866598769.0, 17288117210.0, 60697120725.0, 449068403119.0, 1139905162881.748, 176002520955.0, 144716345530.0, 16278239768.0, 114390594946.069, 48049346000.0, 374152061312.0, 629913807045.0, 51014406245.0, 173861874080.0, 287710479696.0, 452014150210.0, 75963559444.0, 126766531471.0, 16545512949.0, 33889815975.36, 44582437755.0, 133902496559.0, 42061589074.0, 373987767331.0, 38983037128.0, 270939197293.0, 23687180006.0, 268561312608.786, 56004822039.761, 213451584852.644, 142278295363.0, 177109861432.0, 161544082500.0, 81735475149.0, 1120341154127.0, 50254910820.0, 385304233797.0, 64283225607.0])

# %% [markdown]
# ## CON

# %%
def con_score(g):
    con_scores = {} # dictionary of con scores, indices are node names, values are con scores
    for u in g:
        score = 0
        for v in g:
            if u != v:
                common_out_neighbors = set(g.successors(u)).intersection(set(g.successors(v)))
                score = score + len(common_out_neighbors)
        con_scores[u] = score

    return con_scores

def normalized_con_score(g):
    con_scores = {} # dictionary of con scores, indices are node names, values are con scores
    for u in g:
        score = 0
        for v in g:
            if u != v:
                common_out_neighbors = set(g.successors(u)).intersection(set(g.successors(v)))
                score = score + len(common_out_neighbors)
        con_scores[u] = score

    max_con = max(con_scores.values())
    min_con = min(con_scores.values())

    normalized_con_scores = {} # dictionary of con scores, indices are node names, values are normalized con scores
    for u in con_scores:
        normalized_con_scores[u] = (con_scores[u] - min_con) / (max_con - min_con)
    
    return normalized_con_scores

def normalized_weighted_con(g):
    con_scores = {} # dictionary of con scores, indices are node names, values are con scores
    for u in g:
        score = 0
        for v in g:
            if u != v:
                common_out_neighbors = set(g.successors(u)).intersection(set(g.successors(v)))
                for neighbour in common_out_neighbors:
                    score = score + min(g.edges[u,neighbour]['weight'], g.edges[v,neighbour]['weight'])
        con_scores[u] = score

    normalized_con_scores = {} # dictionary of con scores, indices are node names, values are normalized con scores
    max_con = max(con_scores.values())
    min_con = min(con_scores.values())
    for u in con_scores:
        normalized_con_scores[u] = (con_scores[u] - min_con) / (max_con - min_con)

    return normalized_con_scores

# %%
con_2006 = normalized_weighted_con(graph_2006)
con_2006 = {k: v for k, v in sorted(con_2006.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2006.values()
# Out:
# dict_values([0.1999848365744236, 0.11748603104873902, 0.3100967489698673, 0.3936250133971303, 0.0184290258862032, 0.7287885550815024, 0.39336486184975206, 0.4785841351488364, 0.21921082294193361, 1.0, 0.04967545947859144, 0.27131684736579, 0.26973640203634053, 0.0, 0.2603110676119368, 0.8216497875913379, 0.9687932501828938, 0.36478100035850664, 0.29814845977320825, 0.08286777456886124, 0.38464774177724537, 0.171235672727762, 0.7765999469294743, 0.8192659662143111, 0.10196475586434897, 0.4122761489276035, 0.31358830089039397, 0.7224495263596783, 0.18135717799791473, 0.3712981331287929, 0.03245544502748538, 0.06957990964602397, 0.15008255798273487, 0.3081511988158067, 0.14033991009439947, 0.6200691029530039, 0.08530447954338698, 0.5534228478026609, 0.019653781822146246, 0.47011082472591625, 0.19891108306863076, 0.5019708043369904, 0.4458400913330197, 0.5317093857206183, 0.37606062428975856, 0.26303560411678134, 0.8419076903860464, 0.08126845511477494, 0.8265589839286819, 0.140020939923
# ...

# %%
con_2007 = normalized_weighted_con(graph_2007)
con_2007 = {k: v for k, v in sorted(con_2007.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2007.values()
# Out:
# dict_values([0.2422016527772539, 0.18132738786187264, 0.34637253143440017, 0.4258814336750029, 0.07929665257694857, 0.7329308826766182, 0.4289690777517067, 0.49822405757419946, 0.2578202403422807, 1.0, 0.11143549153127803, 0.33096419206890937, 0.30640556462458235, 0.060533017963940276, 0.31684727612544716, 0.8125439902113838, 0.9396172637896294, 0.40486788692130776, 0.33266602419274943, 0.0, 0.40675489185893743, 0.2198333046078342, 0.7807472097470892, 0.7996970840403338, 0.1643744605940154, 0.42739064426479484, 0.34707055688172983, 0.7417813313368081, 0.19119800286661545, 0.4019129504254901, 0.0855785111411201, 0.12836019958626668, 0.18918797360374506, 0.36069128627970687, 0.18907810955257986, 0.6236292851374752, 0.14806176693872466, 0.5355378075337228, 0.08427048567994289, 0.47627668414004964, 0.2546527229679705, 0.530449312361596, 0.4632112662810599, 0.5501579427495159, 0.40896948675986344, 0.31042508757399895, 0.8469337101963577, 0.13708206869339856, 0.7817952742797691, 0.20398164
# ...

# %%
con_2008 = normalized_weighted_con(graph_2008)
con_2008 = {k: v for k, v in sorted(con_2008.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2008.values()
# Out:
# dict_values([0.26058725247015946, 0.1985467084893102, 0.36540299710485014, 0.4133931606247642, 0.07487911979578267, 0.709333809198519, 0.43785575526091813, 0.4816512315734399, 0.22276033641207763, 1.0, 0.11341661977610407, 0.33908009151856094, 0.30283008123033783, 0.09208542504494616, 0.3054020771180447, 0.800640013323846, 0.9333726676174589, 0.42286013703353026, 0.3421497631156708, 0.0, 0.3853589033047718, 0.21740460926657393, 0.759821983602525, 0.7817343313764621, 0.19814095041566399, 0.4162144907235372, 0.3344416831742438, 0.7281600959905928, 0.23206549871294432, 0.4072776798148016, 0.08156785281749414, 0.12200203858897853, 0.17092967717327057, 0.37994435266534915, 0.17796549330361133, 0.6099567249448998, 0.15390492411214202, 0.6204907947609145, 0.08829144456644951, 0.46206475482242465, 0.2508679925081193, 0.517690843386862, 0.4494069121192168, 0.5695129774331296, 0.4043988025368272, 0.31669487063869317, 0.8574245168563477, 0.15512058503844997, 0.7593966028160538, 0.21927842698471
# ...

# %%
con_2009 = normalized_weighted_con(graph_2009)
con_2009 = {k: v for k, v in sorted(con_2009.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2009.values()
# Out:
# dict_values([0.21586834834563706, 0.1971174252924295, 0.3641865193235813, 0.4094165659701489, 0.10199936671001428, 0.7227321688137155, 0.44242957567778335, 0.4835192908121104, 0.23226088310614473, 1.0, 0.1399544867265623, 0.3405519219054459, 0.3117146673566801, 0.10104208642966377, 0.2763336785880243, 0.7952507447880508, 0.9359430180928935, 0.46395553575815446, 0.36649819775346304, 0.0, 0.4220656519065664, 0.21548436610847768, 0.7526344740856921, 0.7604257582009442, 0.17690152698158476, 0.4205688301505834, 0.3319796705191633, 0.7383727233243211, 0.19508444876660358, 0.39899766447916424, 0.09092841939966756, 0.1341102353354119, 0.1761025285572028, 0.3914678266013556, 0.17328415285212156, 0.6179306464404233, 0.165427559214893, 0.5861706771277831, 0.09400595315863228, 0.47486388755901754, 0.23106769637512162, 0.523713490734238, 0.42748496596574326, 0.6030649940336948, 0.43169877870386575, 0.31481244288859217, 0.865835897401554, 0.11150791483903312, 0.7445876277089579, 0.2539935736497490
# ...

# %%
con_2010 = normalized_weighted_con(graph_2010)
con_2010 = {k: v for k, v in sorted(con_2010.items(), key=lambda item: item[0], reverse=False)} # for sorting

con_2010.values()
# Out:
# dict_values([0.15525094692168429, 0.136177439162547, 0.3365149168356051, 0.33162187627240275, 0.02993091246818487, 0.5363487990764648, 0.4214117100335251, 0.4442758177362172, 0.18381989830208056, 1.0, 0.07616017765845715, 0.2750647850996352, 0.22033082999786371, 0.017832979240879586, 0.18811104044476884, 0.7299198880396314, 0.8988379817232454, 0.43184038722147977, 0.34337786050759844, 0.0, 0.32105983276218636, 0.1570005176547278, 0.6803542205307467, 0.7647524430971865, 0.13013022053223336, 0.38454895905838804, 0.291322633142981, 0.6710157432990603, 0.20000116276376248, 0.3108188190312147, 0.016322424588537127, 0.08489824522736561, 0.11541052775400806, 0.3217146366708734, 0.09569375312188828, 0.6145747587580492, 0.09756762900370747, 0.5297628222278282, 0.033250440584211775, 0.45720114909116805, 0.19266884492771236, 0.4521761123788165, 0.3719620962693971, 0.49065530249986194, 0.4001244005930407, 0.24414295486861134, 0.8438648286087156, 0.042807729367612526, 0.6997716583880946, 0.205670
# ...

# %% [markdown]
# ## Clustering

# %%
betweenness = nx.betweenness_centrality(graph_2021)
betweenness_sorted = {k: v for k, v in sorted(betweenness.items(), key=lambda item: item[1], reverse=True)} # for sorting
betweenness_sorted
# Out:
# {'Argentina': 0.00013915281655722673,
#  'Australia': 0.00013915281655722673,
#  'Austria': 0.00013915281655722673,
#  'Belgium': 0.00013915281655722673,
#  'Brazil': 0.00013915281655722673,
#  'Canada': 0.00013915281655722673,
#  'Chile': 0.00013915281655722673,
#  'China': 0.00013915281655722673,
#  'Czechia': 0.00013915281655722673,
#  'Denmark': 0.00013915281655722673,
#  'Finland': 0.00013915281655722673,
#  'France': 0.00013915281655722673,
#  'Germany': 0.00013915281655722673,
#  'Indonesia': 0.00013915281655722673,
#  'Ireland': 0.00013915281655722673,
#  'Italy': 0.00013915281655722673,
#  'Japan': 0.00013915281655722673,
#  'Rep. of Korea': 0.00013915281655722673,
#  'Netherlands': 0.00013915281655722673,
#  'Norway': 0.00013915281655722673,
#  'Philippines': 0.00013915281655722673,
#  'Poland': 0.00013915281655722673,
#  'Portugal': 0.00013915281655722673,
#  'Romania': 0.00013915281655722673,
#  'Russian Federation': 0.00013915281655722673,
# ...
